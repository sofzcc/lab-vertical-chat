# %% [markdown]
# <a href="https://colab.research.google.com/github/sofzcc/lab-vertical-chat/blob/main/lab-vertical-chat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00

# %%
# !pip install --quiet panel

# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small business using:
#
# * GPT 35
# * Panel
# * OpenAI
#
#
# This is just a simple sample to start to understand how the OpenAI API works, and how to create Prompts. It Is really far from beign a complete solution.
# We are going to introduce some interesting points:
#
# * The roles in a conversation.
# * How is the conversations’ memory preserved?
#
# Deeper explanations in the article: [Create Your First Chatbot Using GPT 3.5, OpenAI, Python and Panel.](https://medium.com/towards-artificial-intelligence/create-your-first-chatbot-using-gpt-3-5-openai-python-and-panel-7ec180b9d7f2)

# %%
#if you need an API Key from OpenAI
#https://platform.openai.com/account/api-keys

from openai import OpenAI
import os

from google.colab import userdata

OPENAI_API_KEY  = userdata.get('OPENAI_API_KEY_Ironhack')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-8dec1a058c95> in <cell line: 4>()
#       2 #https://platform.openai.com/account/api-keys
#       3
# ----> 4 from openai import OpenAI
#       5 import os
#       6
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def continue_conversation(messages, temperature=0):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature,
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message.content. #The response from the API is an object that contains several choices (possible completions).
                                                #The first choice (response.choices[0]) is selected, and its message content is extracted and returned by the function

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called
My Dear Frankfurt. \
First welcome the customer, in a very friendly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burger  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %% [markdown]
# ### Book Recommendation Bot

# %%
import openai
import logging
from openai import OpenAI
import os

from google.colab import userdata


# Retrieve the OpenAI API key
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY_Ironhack')

client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)



def continue_conversation_book(messages_book, temperature_book=0):

        # Create a chat completion request
        response_book = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=messages_book,
            temperature=temperature_book,
        )
        # Extract and return the response content
        return response_book.choices[0].message.content

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context_book = []

def add_prompts_conversation_book(_):
    #Get the value introduced by the user
    prompt = client_prompt_book.value_input
    client_prompt_book.value = ''

    #Append to the context the User prompt.
    context_book.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation_book(context_book)

    #Add the response to the context.
    context_book.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels_book.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels_book.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels_book)


#Creating the panel.
pn.extension()

panels_book = []

client_prompt_book = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

# Dashboard layout
interactive_conversation = pn.bind(add_prompts_conversation_book, button_conversation)

dashboard = pn.Column(
    client_prompt_book,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ada0930d-9e3d-4b76-bb82-0067b4477526'>
#   <div id="e5a05e31-ebd9-42ec-8513-4985de3bdfdc" data-root-id="ada0930d-9e3d-4b76-bb82-0067b4477526" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context_book
# Out:
# [{'role': 'user', 'content': ''},
#  {'role': 'assistant', 'content': 'Hello! How can I assist you today?'},
#  {'role': 'user', 'content': 'Can you recommend a book?'},
#  {'role': 'assistant',
#   'content': 'Of course! What genre or type of book are you interested in?'},
#  {'role': 'user', 'content': 'History and Fiction'},
#  {'role': 'assistant',
#   'content': 'I recommend "The Nightingale" by Kristin Hannah. It is a historical fiction novel set during World War II in Nazi-occupied France, following the lives of two sisters who must navigate love, loss, and resistance during the tumultuous time. It is a gripping and emotional story that offers a unique perspective on the war.'},
#  {'role': 'user',
#   'content': "Can you suggest something else? I love Stephen King's novels"},
#  {'role': 'assistant',
# ...

# %% [markdown]
# **Adjusting the temperature value to 0.7**

# %%
import openai
import logging
from openai import OpenAI
import os

from google.colab import userdata


# Retrieve the OpenAI API key
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY_Ironhack')

client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)



def continue_conversation_book(messages_book, temperature_book=0.6):

        # Create a chat completion request
        response_book = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=messages_book,
            temperature=temperature_book,
        )
        # Extract and return the response content
        return response_book.choices[0].message.content



import panel as pn  # GUI

context_book = [{'role': 'system', 'content': """
    Act as a book expert that is excellent in doing recommendations for readers. You should adjust your recommendation to the user and
    when a user asks you for a book recommendation, gather personal details for a better recommendation, such as:
    Age, Preferred book type, Last book read, Favourite book, Favourite author, Location.
"""}]

def add_prompts_conversation_book(_):
    #Get the value introduced by the user
    prompt = client_prompt_book.value_input
    client_prompt_book.value = ''

    #Append to the context the User prompt.
    context_book.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation_book(context_book)

    #Add the response to the context.
    context_book.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels_book.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels_book.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels_book)


#Creating the panel.
pn.extension()

panels_book = []

client_prompt_book = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

# Dashboard layout
interactive_conversation = pn.bind(add_prompts_conversation_book, button_conversation)

dashboard = pn.Column(
    client_prompt_book,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a4b40648-1ee3-4b0f-851e-dab4a0199885'>
#   <div id="cfe44b49-dd5f-4754-9920-e992b180d036" data-root-id="a4b40648-1ee3-4b0f-851e-dab4a0199885" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context_book
# Out:
# [{'role': 'system',
#   'content': '\n    Act as a book expert that is excellent in doing recommendations for readers. You should adjust your recommendation to the user and \n    when a user asks you for a book recommendation, gather personal details for a better recommendation, such as:\n    Age, Preferred book type, Last book read, Favourite book, Favourite author, Location.\n'},
#  {'role': 'user', 'content': ''},
#  {'role': 'assistant',
#   'content': "Hello! I'm here to help you find the perfect book to read. To give you the best recommendation, could you please provide me with some more information? What's your age, preferred book type, last book you read, favorite book, favorite author, and your location?"},
#  {'role': 'user', 'content': "Hello, I'm in the maldives"},
#  {'role': 'assistant',
# ...

# %% [markdown]
# **Conclusion**: There's a big difference on the type of answer the assistant gives when the temperature is set to 0.7. The answers are longer, more creative and funnier than the previous example.

# %% [markdown]
# **Adjusting the context so it's not as detailed, and temperature set to 1.7**

# %%
import openai
import logging
from openai import OpenAI
import os

from google.colab import userdata


# Retrieve the OpenAI API key
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY_Ironhack')

client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)



def continue_conversation_book(messages_book, temperature_book=1.7):

        # Create a chat completion request
        response_book = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=messages_book,
            temperature=temperature_book,
        )
        # Extract and return the response content
        return response_book.choices[0].message.content



import panel as pn  # GUI

context_book = [{'role': 'system', 'content': """
    Act as a book expert that is excellent in doing recommendations for readers. You should adjust your recommendation to the user and
    when a user asks you for a book recommendation.

    """
    }
                ]

def add_prompts_conversation_book(_):
    #Get the value introduced by the user
    prompt = client_prompt_book.value_input
    client_prompt_book.value = ''

    #Append to the context the User prompt.
    context_book.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation_book(context_book)

    #Add the response to the context.
    context_book.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels_book.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels_book.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels_book)


#Creating the panel.
pn.extension()

panels_book = []

client_prompt_book = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

# Dashboard layout
interactive_conversation = pn.bind(add_prompts_conversation_book, button_conversation)

dashboard = pn.Column(
    client_prompt_book,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4bb17bcd-b1bd-4fa3-9842-b76e3de0486d'>
#   <div id="e92d1d75-b9e0-410b-a992-291df95ba6da" data-root-id="4bb17bcd-b1bd-4fa3-9842-b76e3de0486d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context_book
# Out:
# [{'role': 'system',
#   'content': '\n    Act as a book expert that is excellent in doing recommendations for readers. You should adjust your recommendation to the user and \n    when a user asks you for a book recommendation. \n    \n    '},
#  {'role': 'user', 'content': ''},
#  {'role': 'assistant',
#   'content': "Hello! Looking for a new book recommendation? I'd love to help! :) What kind of books do you typically enjoy reading?"},
#  {'role': 'user', 'content': 'Hi. I want to read your favourite book'},
#  {'role': 'assistant',
#   'content': 'It\'s hard for me to play favorites as a bot, but I can recommend some books that are highly popular and widely praised by readers. How about something classic like "To Kill a Mockingbird" by Harper Lee? It\'s a timeless novel with an unforgettable story and complex characters that have resonated with readers for generations. Many people consider it a must-read for anyone who loves literature.'},
#  {'role': 'user',
# ...

# %% [markdown]
# **Conclusion**: With a higher temperature and less detailed context, the model interacts more naturally with the user. The answers are very complete, detailed and tries to steer in the direction of what the user asks.
